# %% [markdown]
# # UFC Descriptive Statistics

# %% [markdown]
# ## List of Contents:
# ## 01. Import Libraries
# ## 02. Import Data
# ## 03. Descriptive Statistics
#
#
# ## --

# %% [markdown]
# ## 01. Import Libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Import Data

# %%
#Defining path for data import
path = r'C:\Users\Mosspants\Desktop\CareerFoundry\A6_Advanced Analytics & Dashboard Design\UFC_Project\02_Data'

# %%
#Importing data
df_ufc = pd.read_csv(os.path.join(path, 'Prepared_Data', 'ufc_cleaned.csv'), index_col = False)

# %%
#Checking import
df_ufc.head()
# Out:
#    Unnamed: 0      R_fighter          B_fighter        Referee  \
# 0           0   Adrian Yanez      Gustavo Lopez  Chris Tognoni
# 1           1   Trevin Giles      Roman Dolidze      Herb Dean
# 2           2    Tai Tuivasa    Harry Hunsucker      Herb Dean
# 3           3  Cheyanne Buys  Montserrat Conejo     Mark Smith
# 4           4  Marion Reneau      Macy Chiasson     Mark Smith
#
#                  location Winner  title_bout       weight_class  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight
#
#    B_total_time_fought(seconds)  B_total_rounds_fought  ...  \
# 0                      531.5000                      4  ...
# 1                      577.5000                      4  ...
# ...

# %% [markdown]
# ## 03. Descriptive Statistics

# %%
#Using describe to get statistics
df_ufc.describe()
# Out:
#         Unnamed: 0  B_total_time_fought(seconds)  B_total_rounds_fought  \
# count  5809.000000                   5809.000000            5809.000000
# mean   2904.000000                    623.295178               9.713892
# std    1677.058188                    226.262011              11.979555
# min       0.000000                      7.000000               0.000000
# 25%    1452.000000                    497.750000               1.000000
# 50%    2904.000000                    643.937500               6.000000
# 75%    4356.000000                    787.910515              14.000000
# max    5808.000000                   1500.000000              94.000000
#
#        B_total_title_bouts  B_current_win_streak  B_current_lose_streak  \
# count          5809.000000           5809.000000            5809.000000
# mean              0.278189              0.956275               0.407127
# std               1.138970              1.497294               0.671403
# ...

# %%
#Assigning output of describe
stats = df_ufc.describe()

# %%
#Exporting to clipboard
stats.to_clipboard()

# %%
#Mode for Referee
df_ufc['Referee'].mode()
# Out:
# 0    Herb Dean
# Name: Referee, dtype: object

# %%
#Mode for location
df_ufc['location'].mode()
# Out:
# 0    Las Vegas, Nevada, USA
# Name: location, dtype: object

# %%
#Mode for weight_class
df_ufc['weight_class'].mode()
# Out:
# 0    Welterweight
# Name: weight_class, dtype: object

# %%
#Mode for B_Stance
df_ufc['B_Stance'].mode()
# Out:
# 0    Orthodox
# Name: B_Stance, dtype: object

# %%
#Mode for R_Stance
df_ufc['R_Stance'].mode()
# Out:
# 0    Orthodox
# Name: R_Stance, dtype: object

# %% [markdown]
# ### No changes made to data, no need to export.
